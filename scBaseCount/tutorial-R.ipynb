# %% [markdown]
# ### [!IMPORTANT]
# **Data Migration Notice**: Arc's Virtual Cell Atlas data has migrated to the [Google Cloud Marketplace](https://console.cloud.google.com/marketplace/product/bigquery-public-data/arc-institute?project=gcp-public-data-arc-institute).
#
# **Note**: The new bucket is subject to [Requester Pays](https://docs.cloud.google.com/storage/docs/requester-pays). Users can access up to 2TB of data per month for free before fees apply.
#
# Access to the current GCS buckets (`gs://arc-ctc-tahoe100/` and `gs://arc-scbasecount/`) will be deprecated on **March 31, 2026**. Please update your workflows to use the Google Marketplace bucket `gs://arc-institute-virtual-cell-atlas`.

# %% [markdown]
# # Summary
#
# * This is a tutorial on using R (& Python via [Reticulate](https://rstudio.github.io/reticulate/))
#   for accessing the scBaseCount dataset hosted by the Arc Institute.
# * The data can be streamed or downloaded locally.
#   * For small jobs (e.g., summarizing the some metadata), streaming is recommended.
#   * For large jobs (e.g., training a model), downloading is recommended.
# * See the [README](README.md#metadata) for a description of the obs metadata.

# %% [markdown]
# # Setup

# %% [markdown]
# ### Installation
#
# If needed, install the necessary dependencies.
#
# You can use the [conda environment](../conda_envs/R.yml) provided in this git repository.

# %% [markdown]
# # Load libraries

# %%
# Load required libraries
library(dplyr)
library(arrow)
library(reticulate)
library(googleCloudStorageR)
os = import("os")
pd = import("pandas")
ad = import("anndata")
gcsfs = import("gcsfs")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp

# %%
# set max print rows
options(repr.matrix.max.rows=4)

# %% [markdown]
# # Data location

# %%
# GCS bucket path
gcs_base_path = "gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12"

# %%
# which STARsolo feature type to use?
feature_type = "GeneFull_Ex50pAS"

# %% [markdown]
# # List available files
#
# Let's see what we have to work with!

# %%
# initialize GCS file system for reading data from GCS
fs = gcsfs$GCSFileSystem(
    token = Sys.getenv("GOOGLE_APPLICATION_CREDENTIALS")
)

# %%
# helper function
get_parquet_files = function(gcs_base_path, feature_type, target = NULL, endswith = NULL) {
  files = fs$glob(os$path$join(gcs_base_path, feature_type, "**"))
  

  if (!is.null(target)) {
    files = files[sapply(files, function(f) basename(f) == target)]
  } else if (!is.null(endswith)) {
    files = files[sapply(files, function(f) grepl(paste0(endswith, "$"), f))]
  }
  
  file_list = lapply(files, function(f) {
    parts = unlist(strsplit(f, "/"))
    c(parts[length(parts)-1], f)
  })
  
  file_df = as.data.frame(do.call(rbind, file_list), stringsAsFactors = FALSE)
  colnames(file_df) = c("organism", "file_path")
  
  return(file_df)
}

# %%
# function to read parquet files from GCS
read_data = function(file, n = NULL){
  if(!startsWith(file, "gs://")){
    file = paste0("gs://", file)
  }
  dataset = open_dataset(file, format = "parquet")
  if (is.null(n)) {
    dataset %>% collect() %>% as.data.frame()
  } else {
    dataset %>% head(n) %>% collect() %>% as.data.frame()
  }
}

# %% [markdown]
# ## Parquet files
#
# * Contain the obs metadata
# * Similar to CSV files, but more efficient for large datasets

# %%
# set the path to the metadata files
gcs_path = file.path(gcs_base_path, "metadata")
gcs_path
# Out:
# [1] "gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata"

# %%
# list files
sample_pq_files = get_parquet_files(gcs_path, feature_type, "sample_metadata.parquet")
sample_pq_files
# Out:
#    organism
# 1  Arabidopsis_thaliana
# 2  Bos_taurus
# ⋮  ⋮
# 26 Taeniopygia_guttata
# 27 Zea_mays
#    file_path
# 1  arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Arabidopsis_thaliana/sample_metadata.parquet
# 2  arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Bos_taurus/sample_metadata.parquet
# ⋮  ⋮
# 26 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Taeniopygia_guttata/sample_metadata.parquet
# 27 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Zea_mays/sample_metadata.parquet

# %% [markdown]
# ### Per-obs metadata

# %%
# list files
obs_pq_files = get_parquet_files(gcs_path, feature_type, "obs_metadata.parquet")
obs_pq_files
# Out:
#    organism
# 1  Arabidopsis_thaliana
# 2  Bos_taurus
# ⋮  ⋮
# 26 Taeniopygia_guttata
# 27 Zea_mays
#    file_path
# 1  arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Arabidopsis_thaliana/obs_metadata.parquet
# 2  arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Bos_taurus/obs_metadata.parquet
# ⋮  ⋮
# 26 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Taeniopygia_guttata/obs_metadata.parquet
# 27 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/metadata/GeneFull_Ex50pAS/Zea_mays/obs_metadata.parquet

# %% [markdown]
# # h5ad files

# %%
gcs_path = file.path(gcs_base_path, "h5ad")
gcs_path
# Out:
# [1] "gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad"

# %%
# list files
h5ad_files = get_parquet_files(gcs_path, feature_type, endswith=".h5ad")
h5ad_files
# Out:
#       organism
# 1     Arabidopsis_thaliana
# 2     Arabidopsis_thaliana
# ⋮     ⋮
# 61377 Zea_mays
# 61378 Zea_mays
#       file_path
# 1     arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/ERX6221408.h5ad
# 2     arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/ERX6221414.h5ad
# ⋮     ⋮
# 61377 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Zea_mays/SRX8487984.h5ad
# 61378 arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Zea_mays/SRX8781690.h5ad

# %% [markdown]
# # Expore the observation metadata
#
# * `obs` ≃ cell

# %% [markdown]
# ### Per-sample
#
# * Useful for quickly summarizing the per-sample metadata (a small file versus the entire obs metadata file; see below).
# * For this tutorial, we will just read in a subset

# %%
# read the metadata files
num_organisms = 2
num_samples_per_organism = 10
sample_metadata = sample_pq_files %>%
  pull(file_path) %>%
  head(n = num_organisms) %>%
  lapply(read_data, n = num_samples_per_organism) %>%
  bind_rows()
sample_metadata
# Out:
#    entrez_id srx_accession
# 1  26779669  SRX19498703
# 2  20529885  SRX14437315
# ⋮  ⋮         ⋮
# 19 18826607  SRX13557914
# 20 18826600  SRX13557907
#    file_path
# 1  gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX19498703.h5ad
# 2  gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX14437315.h5ad
# ⋮  ⋮
# 19 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557914.h5ad
# 20 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557907.h5ad
#    obs_count lib_prep     tech_10x    cell_prep      organism
# 1   2865     10x_Genomics 3_prime_gex single_nucleus Arabidopsis thaliana
# 2  15115     10x_Genomics 3_prime_gex single_cell    Arabidopsis thaliana
# ⋮  ⋮         ⋮            ⋮           ⋮              ⋮
# 19 13304     10x_Genomics 3_prime_gex single_cell    Bos taurus
# 20 12649     10x_Genomics 3_prime_gex single_cell    Bos taurus
#    tissue        tissue_ontology_term_id disease disease_ontology_term_id
# 1  whole flowers UBERON:0000914          unsure  NA
# 2  root tip                              unsure  NA
# ⋮  ⋮             ⋮                       ⋮       ⋮
# 19 cecum         UBERON:0001153          unsure  NA
# 20 omasum        UBERON:0007362          unsure  NA
#    perturbation                 cell_line      antibody_derived_tag
# 1  unsure                       not_applicable no
# 2  half MS (0.5x) growth medium Col-0 cells    no
# ⋮  ⋮                            ⋮              ⋮
# 19 unsure                       unsure         no
# 20 unsure                       unsure         no
#    czi_collection_id czi_collection_name
# 1  NA                NA
# 2  NA                NA
# ⋮  ⋮                 ⋮
# 19 NA                NA
# 20 NA                NA

# %%
# samples per organism
sample_metadata %>% count(organism)
# Out:
#   organism             n
# 1 Arabidopsis thaliana 10
# 2 Bos taurus           10

# %%
# cell counts per sample
sample_metadata %>% pull(obs_count) %>% summary()
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     951    3856   11318    9642   13924   23594

# %%
# cell count distribution per organism
sample_metadata %>%
  group_by(organism) %>%
  summarise(
    min = min(obs_count),
    max = max(obs_count),
    mean = mean(obs_count),
    median = median(obs_count),
    sd = sd(obs_count)
  )
# Out:
#   organism             min  max   mean    median  sd
# 1 Arabidopsis thaliana  951 23594  7152.9  3595.5 7642.408
# 2 Bos taurus           4471 16351 12130.3 12609.0 3541.196

# %% [markdown]
# ### Per-obs metadata

# %%
# read the metadata files
num_organisms = 2
num_obs_per_organism = 1000
obs_metadata = obs_pq_files %>%
  pull(file_path) %>%
  head(n = num_organisms) %>%
  lapply(read_data, n = num_obs_per_organism) %>%
  bind_rows()
obs_metadata
# Out:
#      cell_barcode     SRX_accession gene_count_Unique umi_count_Unique
# 1    AAACCTGAGATATGCA ERX6221408    814               1026
# 2    AAACCTGAGGCGATAC ERX6221408    475                602
# ⋮    ⋮                ⋮             ⋮                 ⋮
# 1999 AGAGCAGAGCTCCACG ERX13041271   3639              9688
# 2000 AGAGCAGAGGATTTAG ERX13041271   3333              8109
#      gene_count_UniqueAndMult-EM umi_count_UniqueAndMult-EM
# 1    822                         1031
# 2    483                          608
# ⋮    ⋮                           ⋮
# 1999 3753                        10335
# 2000 3447                         8563
#      gene_count_UniqueAndMult-Uniform umi_count_UniqueAndMult-Uniform cell_type
# 1    822                              1031
# 2    483                               608
# ⋮    ⋮                                ⋮                               ⋮
# 1999 3908                             10335
# 2000 3568                              8563
#      cell_ontology_term_id
# 1
# 2
# ⋮    ⋮
# 1999
# 2000

# %%
# gene count distribution
obs_metadata %>% pull(gene_count_Unique) %>% summary()
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     108     735    1834    2591    4410    8044

# %%
# umi counts distribution
obs_metadata %>% pull(umi_count_Unique) %>% summary()
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   500.0   986.8  3111.0  7300.8 12792.5 44458.0

# %% [markdown]
# #### Obs for particular samples
#
# Let's get some obs metadata for particular samples

# %%
# re-print our selected samples
sample_metadata
# Out:
#    entrez_id srx_accession
# 1  26779669  SRX19498703
# 2  20529885  SRX14437315
# ⋮  ⋮         ⋮
# 19 18826607  SRX13557914
# 20 18826600  SRX13557907
#    file_path
# 1  gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX19498703.h5ad
# 2  gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX14437315.h5ad
# ⋮  ⋮
# 19 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557914.h5ad
# 20 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557907.h5ad
#    obs_count lib_prep     tech_10x    cell_prep      organism
# 1   2865     10x_Genomics 3_prime_gex single_nucleus Arabidopsis thaliana
# 2  15115     10x_Genomics 3_prime_gex single_cell    Arabidopsis thaliana
# ⋮  ⋮         ⋮            ⋮           ⋮              ⋮
# 19 13304     10x_Genomics 3_prime_gex single_cell    Bos taurus
# 20 12649     10x_Genomics 3_prime_gex single_cell    Bos taurus
#    tissue        tissue_ontology_term_id disease disease_ontology_term_id
# 1  whole flowers UBERON:0000914          unsure  NA
# 2  root tip                              unsure  NA
# ⋮  ⋮             ⋮                       ⋮       ⋮
# 19 cecum         UBERON:0001153          unsure  NA
# 20 omasum        UBERON:0007362          unsure  NA
#    perturbation                 cell_line      antibody_derived_tag
# 1  unsure                       not_applicable no
# 2  half MS (0.5x) growth medium Col-0 cells    no
# ⋮  ⋮                            ⋮              ⋮
# 19 unsure                       unsure         no
# 20 unsure                       unsure         no
#    czi_collection_id czi_collection_name
# 1  NA                NA
# 2  NA                NA
# ⋮  ⋮                 ⋮
# 19 NA                NA
# 20 NA                NA

# %%
# read the metadata files
target_organisms = sample_metadata %>% pull(organism) %>% unique() %>% gsub(" ", "_", .)
obs_metadata = obs_pq_files %>%
  filter(organism %in% target_organisms) %>%
  pull(file_path) %>%
  lapply(read_data) %>%
  bind_rows()

# join on SRX accession
obs_metadata = sample_metadata %>%
  inner_join(obs_metadata, by = c("srx_accession" = "SRX_accession"))
obs_metadata
# Out:
#        entrez_id srx_accession
# 1      26779669  SRX19498703
# 2      26779669  SRX19498703
# ⋮      ⋮         ⋮
# 192831 18826600  SRX13557907
# 192832 18826600  SRX13557907
#        file_path
# 1      gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX19498703.h5ad
# 2      gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX19498703.h5ad
# ⋮      ⋮
# 192831 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557907.h5ad
# 192832 gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Bos_taurus/SRX13557907.h5ad
#        obs_count lib_prep     tech_10x    cell_prep      organism
# 1      2865      10x_Genomics 3_prime_gex single_nucleus Arabidopsis thaliana
# 2      2865      10x_Genomics 3_prime_gex single_nucleus Arabidopsis thaliana
# ⋮      ⋮         ⋮            ⋮           ⋮              ⋮
# 192831 12649     10x_Genomics 3_prime_gex single_cell    Bos taurus
# 192832 12649     10x_Genomics 3_prime_gex single_cell    Bos taurus
#        tissue        tissue_ontology_term_id ⋯ czi_collection_name
# 1      whole flowers UBERON:0000914          ⋯ NA
# 2      whole flowers UBERON:0000914          ⋯ NA
# ⋮      ⋮             ⋮                       ⋱ ⋮
# 192831 omasum        UBERON:0007362          ⋯ NA
# 192832 omasum        UBERON:0007362          ⋯ NA
#        cell_barcode     gene_count_Unique umi_count_Unique
# 1      AAACCCACAAGACGGT 440               532
# 2      AAACCCACAGAGATTA 407               545
# ⋮      ⋮                ⋮                 ⋮
# 192831 TTTGTTGTCGTTGCCT  438                730
# 192832 TTTGTTGTCTCTATAC 4831              17774
#        gene_count_UniqueAndMult-EM umi_count_UniqueAndMult-EM
# 1      452                         538
# 2      417                         553
# ⋮      ⋮                           ⋮
# 192831  470                          798
# 192832 4920                        18924
#        gene_count_UniqueAndMult-Uniform umi_count_UniqueAndMult-Uniform
# 1      452                              538
# 2      419                              553
# ⋮      ⋮                                ⋮
# 192831  501                               798
# 192832 5092                             18924
#        cell_type cell_ontology_term_id
# 1
# 2
# ⋮      ⋮         ⋮
# 192831
# 192832

# %%
# summarize gene counts per organism
obs_metadata %>%
  group_by(organism) %>%
  summarise(
    min = min(gene_count_Unique),
    max = max(gene_count_Unique),
    mean = mean(gene_count_Unique),
    median = median(gene_count_Unique),
    sd = sd(gene_count_Unique)
  )
# Out:
#   organism             min max   mean     median sd
# 1 Arabidopsis thaliana 85  11860 1518.399  990   1394.469
# 2 Bos taurus           21  10506 2340.934 2228   1529.305

# %%
# summarize umi counts per organism
obs_metadata %>%
  group_by(organism) %>%
  summarise(
    min = min(umi_count_Unique),
    max = max(umi_count_Unique),
    mean = mean(umi_count_Unique),
    median = median(umi_count_Unique),
    sd = sd(umi_count_Unique)
  )
# Out:
#   organism             min max    mean     median sd
# 1 Arabidopsis thaliana 133 249412 4878.628 1783    9267.215
# 2 Bos taurus           500 291897 8674.563 5728   10245.028

# %% [markdown]
# # Load h5ad files

# %%
gcs_auth(json_file = Sys.getenv("GOOGLE_APPLICATION_CREDENTIALS"))

# %%
gcs_base_path
# Out:
# [1] "gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12"

# %%
# example
infile = file.path(gcs_base_path, "h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX16110574.h5ad")

# split bucket and path
bucket = unlist(strsplit(infile, "/"))[3]
path = paste(unlist(strsplit(infile, "/"))[-(1:3)], collapse = "/")

# %%
# create a temp file
temp_file = tempfile(fileext = ".h5ad")

# %%
# Download the file to a temporary location
gcs_get_object(object_name = path, bucket = bucket, saveToDisk = temp_file, overwrite = TRUE)
# Out:
# ℹ Downloading scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana…
#
# ✔ Saved scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Arabidopsis_thaliana/SRX16…
# [1] TRUE

# %%
# read in anndata object
adata = ad$read_h5ad(temp_file)
adata
# Out:
# AnnData object with n_obs × n_vars = 5906 × 31109
#     obs: 'gene_count_Unique', 'umi_count_Unique', 'gene_count_UniqueAndMult-EM', 'umi_count_UniqueAndMult-EM', 'gene_count_UniqueAndMult-Uniform', 'umi_count_UniqueAndMult-Uniform', 'SRX_accession', 'cell_type', 'cell_ontology_term_id'
#     var: 'gene_symbols'
#     layers: 'UniqueAndMult-EM', 'UniqueAndMult-Uniform'

# %% [markdown]
# # Downloading files
#
# You can use [gsutil](https://cloud.google.com/storage/docs/gsutil) to download any of the files in the bucket
# and work with them locally.
#
# For example:
#
# ```bash
# gsutil cp gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Homo_sapiens/ERX4319106.h5ad .
# ```
#
# For large data transfers, it is better to use `gsutil rsync`:
#
# ```bash
# gsutil -m rsync gs://arc-institute-virtual-cell-atlas/scbasecount/2026-01-12/h5ad/GeneFull_Ex50pAS/Callithrix_jacchus/ .
# ```

# %% [markdown]
# ***
#
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 4.2.3 (2023-03-15)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /home/nickyoungblut/miniforge3/envs/scbasecount-r/lib/libopenblasp-r0.3.29.so
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] googleCloudStorageR_0.7.0 reticulate_1.38.0
# [3] arrow_16.1.0              dplyr_1.1.4
#
# loaded via a namespace (and not attached):
#  [1] zip_2.3.1         Rcpp_1.0.12       googleAuthR_2.0.2 pillar_1.9.0
#  [5] compiler_4.2.3    base64enc_0.1-3   tools_4.2.3       digest_0.6.36
#  [9] uuid_1.2-0        bit_4.0.5         gargle_1.5.2      memoise_2.0.1
# [13] jsonlite_1.8.8    evaluate_0.24.0   lifecycle_1.0.4   tibble_3.2.1
# [17] lattice_0.22-6    png_0.1-8         pkgconfig_2.0.3   rlang_1.1.4
# [21] Matrix_1.6-5      IRdisplay_1.1     cli_3.6.3         yaml_2.3.8
# [25] curl_5.1.0        IRkernel_1.3.2    fastmap_1.2.0     withr_3.0.0
# [29] httr_1.4.7        repr_1.1.7        rappdirs_0.3.3    askpass_1.2.0
# [33] fs_1.6.4          generics_0.1.3    vctrs_0.6.5       rprojroot_2.0.4
# [37] bit64_4.0.5       grid_4.2.3        tidyselect_1.2.1  here_1.0.1
# [41] glue_1.7.0        R6_2.5.1          fansi_1.0.6       pbdZMQ_0.3-11
# [45] purrr_1.0.2       magrittr_2.0.3    htmltools_0.5.8.1 assertthat_0.2.1
# [49] utf8_1.2.4        openssl_2.2.0     cachem_1.1.0      crayon_1.5.3
